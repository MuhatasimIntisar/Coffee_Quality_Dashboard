# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("Group5_coffee.csv")

# %%
df.describe()
# Out:
#        Number.of.Bags  Harvest.Year       Aroma      Flavor  Aftertaste  \
# count      772.000000    772.000000  772.000000  772.000000  772.000000
# mean       158.506477   2013.764249    7.566788    7.506969    7.367565
# std        123.843187      1.671107    0.294816    0.328539    0.335685
# min          1.000000   2011.000000    6.330000    6.170000    6.170000
# 25%         20.000000   2012.000000    7.420000    7.330000    7.170000
# 50%        200.000000   2014.000000    7.580000    7.500000    7.420000
# 75%        275.000000   2015.000000    7.750000    7.670000    7.580000
# max        600.000000   2018.000000    8.750000    8.830000    8.670000
#
#           Acidity        Body     Balance  Uniformity   Clean.Cup   Sweetness  \
# count  772.000000  772.000000  772.000000  772.000000  772.000000  772.000000
# mean     7.533601    7.491580    7.483083    9.860777    9.852215    9.934275
# std      0.293133    0.271187    0.334647    0.451443    0.751358    0.417776
# ...

# %%
df.columns
# Out:
# Index(['Species', 'Country.of.Origin', 'Region', 'Producer', 'Number.of.Bags',
#        'In.Country.Partner', 'Harvest.Year', 'Grading.Date',
#        'Processing.Method', 'Aroma', 'Flavor', 'Aftertaste', 'Acidity', 'Body',
#        'Balance', 'Uniformity', 'Clean.Cup', 'Sweetness', 'Cupper.Points',
#        'Total.Cup.Points', 'Moisture', 'altitude_low_meters',
#        'altitude_high_meters', 'altitude_mean_meters'],
#       dtype='str')

# %%
sens = ['Aroma', 'Flavor', 'Aftertaste', 'Acidity', 'Body',
       'Balance', 'Uniformity', 'Clean.Cup', 'Sweetness', 'Cupper.Points',
       'Total.Cup.Points']

# %%
corr = df[sens].corr()

# %%
sns.heatmap(corr, cmap="crest")
# Out:
# <Axes: >
